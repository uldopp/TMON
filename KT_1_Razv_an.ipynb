# %% [markdown]
# <a href="https://colab.research.google.com/github/uldopp/TMON/blob/main/KT_1_Razv_an.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hi')
# Out:
# hi
